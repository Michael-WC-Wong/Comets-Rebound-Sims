# %%
import csv
import glob
import os

txt_files = glob.glob('./Cluster_Output/4.5e9_10000_Rcrit6_LinearChem/*.out')

for txt_file in txt_files:
    with open(txt_file, "rt") as input_file:
        in_txt = csv.reader(input_file, delimiter=" ")
        #Skip first line of file
        next(in_txt)
        #next(in_txt)
        #print(in_txt)
        filename = os.path.splitext(os.path.basename(txt_file))[0] + '.csv'
        
        print(filename)
        with open(os.path.join('./Cluster_Output/4.5e9_10000_Rcrit6_LinearChem/', filename), 'wt') as output_file:
            out_csv = csv.writer(output_file)
            out_csv.writerows(in_txt)
# Out:
# UNMigrate_LinearChem_Rcrit6.csv
# UNMigrate_LinearChem_Rcrit6_1.csv
# UNMigrate_LinearChem_Rcrit6_10.csv
# UNMigrate_LinearChem_Rcrit6_11.csv
# UNMigrate_LinearChem_Rcrit6_12.csv
# UNMigrate_LinearChem_Rcrit6_13.csv
# UNMigrate_LinearChem_Rcrit6_14.csv
# UNMigrate_LinearChem_Rcrit6_15.csv
# UNMigrate_LinearChem_Rcrit6_16.csv
# UNMigrate_LinearChem_Rcrit6_17.csv
# UNMigrate_LinearChem_Rcrit6_18.csv
# UNMigrate_LinearChem_Rcrit6_19.csv
# UNMigrate_LinearChem_Rcrit6_2.csv
# UNMigrate_LinearChem_Rcrit6_20.csv
# UNMigrate_LinearChem_Rcrit6_21.csv
# UNMigrate_LinearChem_Rcrit6_22.csv
# UNMigrate_LinearChem_Rcrit6_23.csv
# UNMigrate_LinearChem_Rcrit6_24.csv
# UNMigrate_LinearChem_Rcrit6_25.csv
# UNMigrate_LinearChem_Rcrit6_26.csv
# UNMigrate_LinearChem_Rcrit6_27.csv
# UNMigrate_LinearChem_Rcrit6_28.csv
# UNMigrate_LinearChem_Rcrit6_29.csv
# UNMigrate_LinearChem_Rcrit6_3.csv
# UNMigrate_LinearChem_Rcrit6_30.csv
# UNMigrate_LinearChem_Rcrit6_31.csv
# UNMigrate_LinearChem_Rcrit6_32.csv
# UNMigrate_LinearChem_Rcrit6_33.csv
# UNMigrate_LinearChem_Rcrit6_34.csv
# UNMigrate_LinearChem_Rcrit6_35.csv
# UNMigrate_LinearChem_Rcrit6_36.csv
# UNMigrate_LinearChem_Rcrit6_37.csv
# UNMigrate_LinearChem_Rcrit6_38.csv
# UNMigrate_LinearChem_Rcrit6_39.csv
# UNMigrate_LinearChem_Rcrit6_4.csv
# UNMigrate_LinearChem_Rcrit6_40.csv
# UNMigrate_LinearChem_Rcrit6_41.csv
# UNMigrate_LinearChem_Rcrit6_42.csv
# UNMigrate_LinearChem_Rcrit6_43.csv
# UNMigrate_LinearChem_Rcrit6_44.csv
# UNMigrate_LinearChem_Rcrit6_45.csv
# UNMigrate_LinearChem_Rcrit6_46.csv
# UNMigrate_LinearChem_Rcrit6_47.csv
# UNMigrate_LinearChem_Rcrit6_48.csv
# UNMigrate_LinearChem_Rcrit6_49.csv
# UNMigrate_LinearChem_Rcrit6_5.csv
# UNMigrate_LinearChem_Rcrit6_50.csv
# UNMigrate_LinearChem_Rcrit6_51.csv
# UNMigrate_LinearChem_Rcrit6_52.csv
# UNMigrate_LinearChem_Rcrit6_53.csv
# UNMigrate_LinearChem_Rcrit6_54.csv
# UNMigrate_LinearChem_Rcrit6_55.csv
# UNMigrate_LinearChem_Rcrit6_56.csv
# UNMigrate_LinearChem_Rcrit6_57.csv
# UNMigrate_LinearChem_Rcrit6_58.csv
# UNMigrate_LinearChem_Rcrit6_59.csv
# UNMigrate_LinearChem_Rcrit6_6.csv
# UNMigrate_LinearChem_Rcrit6_60.csv
# UNMigrate_LinearChem_Rcrit6_61.csv
# UNMigrate_LinearChem_Rcrit6_62.csv
# UNMigrate_LinearChem_Rcrit6_63.csv
# UNMigrate_LinearChem_Rcrit6_64.csv
# UNMigrate_LinearChem_Rcrit6_65.csv
# UNMigrate_LinearChem_Rcrit6_66.csv
# UNMigrate_LinearChem_Rcrit6_67.csv
# UNMigrate_LinearChem_Rcrit6_68.csv
# UNMigrate_LinearChem_Rcrit6_69.csv
# UNMigrate_LinearChem_Rcrit6_7.csv
# UNMigrate_LinearChem_Rcrit6_70.csv
# UNMigrate_LinearChem_Rcrit6_71.csv
# UNMigrate_LinearChem_Rcrit6_72.csv
# UNMigrate_LinearChem_Rcrit6_73.csv
# UNMigrate_LinearChem_Rcrit6_74.csv
# UNMigrate_LinearChem_Rcrit6_75.csv
# UNMigrate_LinearChem_Rcrit6_76.csv
# UNMigrate_LinearChem_Rcrit6_77.csv
# UNMigrate_LinearChem_Rcrit6_78.csv
# UNMigrate_LinearChem_Rcrit6_79.csv
# UNMigrate_LinearChem_Rcrit6_8.csv
# UNMigrate_LinearChem_Rcrit6_80.csv
# UNMigrate_LinearChem_Rcrit6_81.csv
# UNMigrate_LinearChem_Rcrit6_82.csv
# UNMigrate_LinearChem_Rcrit6_83.csv
# UNMigrate_LinearChem_Rcrit6_84.csv
# UNMigrate_LinearChem_Rcrit6_85.csv
# UNMigrate_LinearChem_Rcrit6_86.csv
# UNMigrate_LinearChem_Rcrit6_87.csv
# UNMigrate_LinearChem_Rcrit6_88.csv
# UNMigrate_LinearChem_Rcrit6_89.csv
# UNMigrate_LinearChem_Rcrit6_9.csv
# UNMigrate_LinearChem_Rcrit6_90.csv
# UNMigrate_LinearChem_Rcrit6_91.csv
# UNMigrate_LinearChem_Rcrit6_92.csv
# UNMigrate_LinearChem_Rcrit6_93.csv
# UNMigrate_LinearChem_Rcrit6_94.csv
# UNMigrate_LinearChem_Rcrit6_95.csv
# UNMigrate_LinearChem_Rcrit6_96.csv
# UNMigrate_LinearChem_Rcrit6_97.csv
# UNMigrate_LinearChem_Rcrit6_98.csv
# UNMigrate_LinearChem_Rcrit6_99.csv

# %%
import csv
import glob
import os

txt_files = glob.glob('./Cluster_Output/4.5e9_1000_Rcrit3_LinearChem/*.out')

for txt_file in txt_files:
    with open(txt_file, "rt") as input_file:
        in_txt = csv.reader(input_file, delimiter=",")
        #Skip first line of file
        #next(in_txt)
        #next(in_txt)
        #print(in_txt)
        filename = os.path.splitext(os.path.basename(txt_file))[0] + '.csv'
        
        print(filename)
        with open(os.path.join('./Cluster_Output/4.5e9_1000_Rcrit3_LinearChem/', filename), 'wt') as output_file:
            out_csv = csv.writer(output_file)
            out_csv.writerows(in_txt)
# Out:
# UNMigrate_LinearChem_Rcrit3_.csv
# UNMigrate_LinearChem_Rcrit3_1.csv
# UNMigrate_LinearChem_Rcrit3_10.csv
# UNMigrate_LinearChem_Rcrit3_11.csv
# UNMigrate_LinearChem_Rcrit3_12.csv
# UNMigrate_LinearChem_Rcrit3_13.csv
# UNMigrate_LinearChem_Rcrit3_14.csv
# UNMigrate_LinearChem_Rcrit3_15.csv
# UNMigrate_LinearChem_Rcrit3_16.csv
# UNMigrate_LinearChem_Rcrit3_17.csv
# UNMigrate_LinearChem_Rcrit3_18.csv
# UNMigrate_LinearChem_Rcrit3_19.csv
# UNMigrate_LinearChem_Rcrit3_2.csv
# UNMigrate_LinearChem_Rcrit3_20.csv
# UNMigrate_LinearChem_Rcrit3_21.csv
# UNMigrate_LinearChem_Rcrit3_22.csv
# UNMigrate_LinearChem_Rcrit3_23.csv
# UNMigrate_LinearChem_Rcrit3_24.csv
# UNMigrate_LinearChem_Rcrit3_25.csv
# UNMigrate_LinearChem_Rcrit3_26.csv
# UNMigrate_LinearChem_Rcrit3_27.csv
# UNMigrate_LinearChem_Rcrit3_28.csv
# UNMigrate_LinearChem_Rcrit3_29.csv
# UNMigrate_LinearChem_Rcrit3_3.csv
# UNMigrate_LinearChem_Rcrit3_30.csv
# UNMigrate_LinearChem_Rcrit3_31.csv
# UNMigrate_LinearChem_Rcrit3_32.csv
# UNMigrate_LinearChem_Rcrit3_33.csv
# UNMigrate_LinearChem_Rcrit3_34.csv
# UNMigrate_LinearChem_Rcrit3_35.csv
# UNMigrate_LinearChem_Rcrit3_36.csv
# UNMigrate_LinearChem_Rcrit3_37.csv
# UNMigrate_LinearChem_Rcrit3_38.csv
# UNMigrate_LinearChem_Rcrit3_39.csv
# UNMigrate_LinearChem_Rcrit3_4.csv
# UNMigrate_LinearChem_Rcrit3_40.csv
# UNMigrate_LinearChem_Rcrit3_41.csv
# UNMigrate_LinearChem_Rcrit3_42.csv
# UNMigrate_LinearChem_Rcrit3_43.csv
# UNMigrate_LinearChem_Rcrit3_44.csv
# UNMigrate_LinearChem_Rcrit3_45.csv
# UNMigrate_LinearChem_Rcrit3_46.csv
# UNMigrate_LinearChem_Rcrit3_47.csv
# UNMigrate_LinearChem_Rcrit3_48.csv
# UNMigrate_LinearChem_Rcrit3_49.csv
# UNMigrate_LinearChem_Rcrit3_5.csv
# UNMigrate_LinearChem_Rcrit3_50.csv
# UNMigrate_LinearChem_Rcrit3_51.csv
# UNMigrate_LinearChem_Rcrit3_52.csv
# UNMigrate_LinearChem_Rcrit3_53.csv
# UNMigrate_LinearChem_Rcrit3_54.csv
# UNMigrate_LinearChem_Rcrit3_55.csv
# UNMigrate_LinearChem_Rcrit3_56.csv
# UNMigrate_LinearChem_Rcrit3_57.csv
# UNMigrate_LinearChem_Rcrit3_58.csv
# UNMigrate_LinearChem_Rcrit3_59.csv
# UNMigrate_LinearChem_Rcrit3_6.csv
# UNMigrate_LinearChem_Rcrit3_60.csv
# UNMigrate_LinearChem_Rcrit3_61.csv
# UNMigrate_LinearChem_Rcrit3_62.csv
# UNMigrate_LinearChem_Rcrit3_63.csv
# UNMigrate_LinearChem_Rcrit3_64.csv
# UNMigrate_LinearChem_Rcrit3_65.csv
# UNMigrate_LinearChem_Rcrit3_66.csv
# UNMigrate_LinearChem_Rcrit3_67.csv
# UNMigrate_LinearChem_Rcrit3_68.csv
# UNMigrate_LinearChem_Rcrit3_69.csv
# UNMigrate_LinearChem_Rcrit3_7.csv
# UNMigrate_LinearChem_Rcrit3_70.csv
# UNMigrate_LinearChem_Rcrit3_71.csv
# UNMigrate_LinearChem_Rcrit3_72.csv
# UNMigrate_LinearChem_Rcrit3_73.csv
# UNMigrate_LinearChem_Rcrit3_74.csv
# UNMigrate_LinearChem_Rcrit3_75.csv
# UNMigrate_LinearChem_Rcrit3_76.csv
# UNMigrate_LinearChem_Rcrit3_77.csv
# UNMigrate_LinearChem_Rcrit3_78.csv
# UNMigrate_LinearChem_Rcrit3_79.csv
# UNMigrate_LinearChem_Rcrit3_8.csv
# UNMigrate_LinearChem_Rcrit3_80.csv
# UNMigrate_LinearChem_Rcrit3_81.csv
# UNMigrate_LinearChem_Rcrit3_82.csv
# UNMigrate_LinearChem_Rcrit3_83.csv
# UNMigrate_LinearChem_Rcrit3_84.csv
# UNMigrate_LinearChem_Rcrit3_85.csv
# UNMigrate_LinearChem_Rcrit3_86.csv
# UNMigrate_LinearChem_Rcrit3_87.csv
# UNMigrate_LinearChem_Rcrit3_88.csv
# UNMigrate_LinearChem_Rcrit3_89.csv
# UNMigrate_LinearChem_Rcrit3_9.csv
# UNMigrate_LinearChem_Rcrit3_90.csv
# UNMigrate_LinearChem_Rcrit3_91.csv
# UNMigrate_LinearChem_Rcrit3_92.csv
# UNMigrate_LinearChem_Rcrit3_93.csv
# UNMigrate_LinearChem_Rcrit3_94.csv
# UNMigrate_LinearChem_Rcrit3_95.csv
# UNMigrate_LinearChem_Rcrit3_96.csv
# UNMigrate_LinearChem_Rcrit3_97.csv
# UNMigrate_LinearChem_Rcrit3_98.csv
# UNMigrate_LinearChem_Rcrit3_99.csv
